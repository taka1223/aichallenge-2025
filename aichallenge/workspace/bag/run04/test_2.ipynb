# %%
import polars as pl

# %%
df = pl.read_parquet("actual_speed.parquet")
df
# Out:
# shape: (5_361, 2)
# ┌──────────────┬────────────┐
# │ actual_speed ┆ t          │
# │ ---          ┆ ---        │
# │ f64          ┆ f64        │
# ╞══════════════╪════════════╡
# │ 0.0          ┆ 0.0        │
# │ 0.019355     ┆ 0.146408   │
# │ 0.019522     ┆ 0.154137   │
# │ 0.019522     ┆ 0.167237   │
# │ 0.019522     ┆ 0.186831   │
# │ …            ┆ …          │
# │ 5.285133     ┆ 108.17649  │
# │ 5.287915     ┆ 108.20022  │
# │ 5.287915     ┆ 108.221447 │
# │ 5.287937     ┆ 108.246325 │
# │ 5.29196      ┆ 108.266257 │
# └──────────────┴────────────┘
